# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('student.csv')

# %%
df
# Out:
#     รหัสนักศึกษา      ชื่อ   อายุ     เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0          64001     สมชาย   20.0     ชาย     วิทยาศาสตร์  3.21       170.0
# 1          64002    สมหญิง   21.0    หญิง           วิทย์  3.45       165.0
# 2          64003       NaN    NaN    Male         Science  3.67       175.0
# 3          64004  สมศักดิ์   22.0       ช  คณะวิทยาศาสตร์ -1.00       168.0
# 4          64005      สมใจ   19.0       ญ           วิศวะ  3.89       160.0
# 5          64006     กานต์  150.0     ชาย     Engineering  3.12       172.0
# 6          64007     กิตติ   21.0    หญิง        วิศวกรรม  4.50       158.0
# 7          64008      จิรา   20.0       F      ศิลปศาสตร์  2.98       180.0
# 8          64009    ชนาธิป   23.0       M            Arts  3.34       163.0
# 9          64010      ดารา   21.0    หญิง           ศิลป์  3.56       167.0
# 10         64011      ธีระ    NaN     NaN             NaN  3.78         NaN
# ...

# %%
df.head()
# Out:
#    รหัสนักศึกษา      ชื่อ  อายุ   เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0         64001     สมชาย  20.0   ชาย     วิทยาศาสตร์  3.21       170.0
# 1         64002    สมหญิง  21.0  หญิง           วิทย์  3.45       165.0
# 2         64003       NaN   NaN  Male         Science  3.67       175.0
# 3         64004  สมศักดิ์  22.0     ช  คณะวิทยาศาสตร์ -1.00       168.0
# 4         64005      สมใจ  19.0     ญ           วิศวะ  3.89       160.0
#
#    น้ำหนัก_kg  ชั่วโมงเรียน_ต่อสัปดาห์ วันที่ลงทะเบียน
# 0        65.0                     15.0      2024-02-13
# 1        58.0                     20.0      2023-12-31
# 2         NaN                     25.0      2023-12-30
# 3        70.0                     10.0      2024-01-31
# 4        52.0                     30.0      2024-02-04

# %% [markdown]
# # **ลบ'ชื่อ'ที่มีค่าเป็น NaN**

# %%
df = df.dropna(subset=['ชื่อ'])

# %%
df
# Out:
#     รหัสนักศึกษา      ชื่อ   อายุ     เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0          64001     สมชาย   20.0     ชาย     วิทยาศาสตร์  3.21       170.0
# 1          64002    สมหญิง   21.0    หญิง           วิทย์  3.45       165.0
# 3          64004  สมศักดิ์   22.0       ช  คณะวิทยาศาสตร์ -1.00       168.0
# 4          64005      สมใจ   19.0       ญ           วิศวะ  3.89       160.0
# 5          64006     กานต์  150.0     ชาย     Engineering  3.12       172.0
# 6          64007     กิตติ   21.0    หญิง        วิศวกรรม  4.50       158.0
# 7          64008      จิรา   20.0       F      ศิลปศาสตร์  2.98       180.0
# 8          64009    ชนาธิป   23.0       M            Arts  3.34       163.0
# 9          64010      ดารา   21.0    หญิง           ศิลป์  3.56       167.0
# 10         64011      ธีระ    NaN     NaN             NaN  3.78         NaN
# 11         64012       นภา   22.0     ชาย           วิทย์   NaN       171.0
# ...

# %% [markdown]
# # **ลบ**'อายุ' ที่มีค่าผิดปกติ โดยที่ค่า NaN ยังอยู่

# %%
Q1 = df['อายุ'].quantile(0.25)
Q3 = df['อายุ'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = ((df['อายุ'] >= Q1 - 1.5 * IQR) & (df['อายุ'] <= Q3 + 1.5 * IQR)) | df['อายุ'].isna()

df = df[outliers]

# %%
df
# Out:
#     รหัสนักศึกษา      ชื่อ  อายุ     เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0          64001     สมชาย  20.0     ชาย     วิทยาศาสตร์  3.21       170.0
# 1          64002    สมหญิง  21.0    หญิง           วิทย์  3.45       165.0
# 3          64004  สมศักดิ์  22.0       ช  คณะวิทยาศาสตร์ -1.00       168.0
# 4          64005      สมใจ  19.0       ญ           วิศวะ  3.89       160.0
# 6          64007     กิตติ  21.0    หญิง        วิศวกรรม  4.50       158.0
# 7          64008      จิรา  20.0       F      ศิลปศาสตร์  2.98       180.0
# 8          64009    ชนาธิป  23.0       M            Arts  3.34       163.0
# 9          64010      ดารา  21.0    หญิง           ศิลป์  3.56       167.0
# 10         64011      ธีระ   NaN     NaN             NaN  3.78         NaN
# 11         64012       นภา  22.0     ชาย           วิทย์   NaN       171.0
# 12         64013     บุญมี  20.0    หญิง           วิศวฯ  3.23       169.0
# ...

# %% [markdown]
# # ใส่ค่าเฉลี่ยของอายุ ในคอลัมน์ 'อายุ' ที่เป็นค่า **NaN**

# %%
mean_age = df['อายุ'].mean()
df['อายุ'].fillna(mean_age, inplace=True)

# %%
df
# Out:
#     รหัสนักศึกษา      ชื่อ    อายุ     เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0          64001     สมชาย  20.000     ชาย     วิทยาศาสตร์  3.21       170.0
# 1          64002    สมหญิง  21.000    หญิง           วิทย์  3.45       165.0
# 3          64004  สมศักดิ์  22.000       ช  คณะวิทยาศาสตร์ -1.00       168.0
# 4          64005      สมใจ  19.000       ญ           วิศวะ  3.89       160.0
# 6          64007     กิตติ  21.000    หญิง        วิศวกรรม  4.50       158.0
# 7          64008      จิรา  20.000       F      ศิลปศาสตร์  2.98       180.0
# 8          64009    ชนาธิป  23.000       M            Arts  3.34       163.0
# 9          64010      ดารา  21.000    หญิง           ศิลป์  3.56       167.0
# 10         64011      ธีระ  20.875     NaN             NaN  3.78         NaN
# 11         64012       นภา  22.000     ชาย           วิทย์   NaN       171.0
# 12         64013     บุญมี  20.000    หญิง           วิศวฯ  3.23       169.0
# ...

# %% [markdown]
# # แปลงค่าทศนิยมที่คอลัมน์ 'อายุ' **ให้เป็นจำนวนเต็ม**

# %%
df['อายุ'] = df['อายุ'].astype(int)

# %%
df
# Out:
#     รหัสนักศึกษา      ชื่อ  อายุ     เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0          64001     สมชาย    20     ชาย     วิทยาศาสตร์  3.21       170.0
# 1          64002    สมหญิง    21    หญิง           วิทย์  3.45       165.0
# 3          64004  สมศักดิ์    22       ช  คณะวิทยาศาสตร์ -1.00       168.0
# 4          64005      สมใจ    19       ญ           วิศวะ  3.89       160.0
# 6          64007     กิตติ    21    หญิง        วิศวกรรม  4.50       158.0
# 7          64008      จิรา    20       F      ศิลปศาสตร์  2.98       180.0
# 8          64009    ชนาธิป    23       M            Arts  3.34       163.0
# 9          64010      ดารา    21    หญิง           ศิลป์  3.56       167.0
# 10         64011      ธีระ    20     NaN             NaN  3.78         NaN
# 11         64012       นภา    22     ชาย           วิทย์   NaN       171.0
# 12         64013     บุญมี    20    หญิง           วิศวฯ  3.23       169.0
# ...

# %% [markdown]
# # **ทำคอลัมน์ 'เพศ' ให้เป็นค่ามาตรฐาน**

# %%
def standardize_faculty(name):
    if name in ['ชาย', 'ช', 'M', 'Male']:
        return 'ชาย'
    elif name in ['หญิง', 'ญ', 'F', 'Female']:
        return 'หญิง'
    else:
        return name

df['เพศ'] = df['เพศ'].apply(standardize_faculty)

# %% [markdown]
# # ใส่ข้อมูลในคอลัมน์ 'เพศ' ที่เป็นค่า NaN **โดยเติมค่าด้วยค่าที่พบบ่อยที่สุด**

# %%
df['เพศ'].fillna(df['เพศ'].mode()[0], inplace=True)

# %%
df
# Out:
#     รหัสนักศึกษา      ชื่อ  อายุ   เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0          64001     สมชาย    20   ชาย     วิทยาศาสตร์  3.21       170.0
# 1          64002    สมหญิง    21  หญิง           วิทย์  3.45       165.0
# 3          64004  สมศักดิ์    22   ชาย  คณะวิทยาศาสตร์ -1.00       168.0
# 4          64005      สมใจ    19  หญิง           วิศวะ  3.89       160.0
# 6          64007     กิตติ    21  หญิง        วิศวกรรม  4.50       158.0
# 7          64008      จิรา    20  หญิง      ศิลปศาสตร์  2.98       180.0
# 8          64009    ชนาธิป    23   ชาย            Arts  3.34       163.0
# 9          64010      ดารา    21  หญิง           ศิลป์  3.56       167.0
# 10         64011      ธีระ    20  หญิง             NaN  3.78         NaN
# 11         64012       นภา    22   ชาย           วิทย์   NaN       171.0
# 12         64013     บุญมี    20  หญิง           วิศวฯ  3.23       169.0
# 13         64014     ปรีชา    21   ชาย    Liberal Arts  3.45       164.0
# ...

# %% [markdown]
# # **ทำคอลัมน์ 'คณะ' ให้เป็นค่ามาตรฐาน**

# %%
def standardize_faculty(name):
    if name in ['วิทยาศาสตร์', 'วิทย์', 'Science', 'คณะวิทยาศาสตร์', 'Sci']:
        return 'วิทยาศาสตร์'
    elif name in ['ศิลปศาสตร์', 'ศิลป์', 'Arts', 'Liberal Arts']:
        return 'ศิลปศาสตร์'
    elif name in ['วิศวกรรมศาสตร์', 'วิศวฯ', 'วิศวกรรม', 'วิศวะ']:
        return 'วิศวกรรมศาสตร์'
    else:
        return name

df['คณะ'] = df['คณะ'].apply(standardize_faculty)

# %%
df
# Out:
#     รหัสนักศึกษา      ชื่อ  อายุ   เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0          64001     สมชาย    20   ชาย     วิทยาศาสตร์  3.21       170.0
# 1          64002    สมหญิง    21  หญิง     วิทยาศาสตร์  3.45       165.0
# 3          64004  สมศักดิ์    22   ชาย     วิทยาศาสตร์ -1.00       168.0
# 4          64005      สมใจ    19  หญิง  วิศวกรรมศาสตร์  3.89       160.0
# 6          64007     กิตติ    21  หญิง  วิศวกรรมศาสตร์  4.50       158.0
# 7          64008      จิรา    20  หญิง      ศิลปศาสตร์  2.98       180.0
# 8          64009    ชนาธิป    23   ชาย      ศิลปศาสตร์  3.34       163.0
# 9          64010      ดารา    21  หญิง      ศิลปศาสตร์  3.56       167.0
# 10         64011      ธีระ    20  หญิง             NaN  3.78         NaN
# 11         64012       นภา    22   ชาย     วิทยาศาสตร์   NaN       171.0
# 12         64013     บุญมี    20  หญิง  วิศวกรรมศาสตร์  3.23       169.0
# 13         64014     ปรีชา    21   ชาย      ศิลปศาสตร์  3.45       164.0
# ...

# %% [markdown]
# # **ใส่ข้อมูลในคอลัมน์ 'คณะ' ที่เป็นค่า NaN โดยเติมค่าด้วยค่าที่พบบ่อยที่สุด**

# %%
df['คณะ'].fillna(df['คณะ'].mode()[0], inplace=True)

# %%
df
# Out:
#     รหัสนักศึกษา      ชื่อ  อายุ   เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0          64001     สมชาย    20   ชาย     วิทยาศาสตร์  3.21       170.0
# 1          64002    สมหญิง    21  หญิง     วิทยาศาสตร์  3.45       165.0
# 3          64004  สมศักดิ์    22   ชาย     วิทยาศาสตร์ -1.00       168.0
# 4          64005      สมใจ    19  หญิง  วิศวกรรมศาสตร์  3.89       160.0
# 6          64007     กิตติ    21  หญิง  วิศวกรรมศาสตร์  4.50       158.0
# 7          64008      จิรา    20  หญิง      ศิลปศาสตร์  2.98       180.0
# 8          64009    ชนาธิป    23   ชาย      ศิลปศาสตร์  3.34       163.0
# 9          64010      ดารา    21  หญิง      ศิลปศาสตร์  3.56       167.0
# 10         64011      ธีระ    20  หญิง     วิทยาศาสตร์  3.78         NaN
# 11         64012       นภา    22   ชาย     วิทยาศาสตร์   NaN       171.0
# 12         64013     บุญมี    20  หญิง  วิศวกรรมศาสตร์  3.23       169.0
# 13         64014     ปรีชา    21   ชาย      ศิลปศาสตร์  3.45       164.0
# ...

# %% [markdown]
# # ทำคอลัมน์ 'GPA' ที่มีค่าผิดปกติให้เป็นค่า **NaN**

# %%
df.loc[((df['GPA'] < 0) | (df['GPA'] > 4.00)) & df['อายุ'].notna(), 'GPA'] = np.nan

# %%
df
# Out:
#     รหัสนักศึกษา      ชื่อ  อายุ   เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0          64001     สมชาย    20   ชาย     วิทยาศาสตร์  3.21       170.0
# 1          64002    สมหญิง    21  หญิง     วิทยาศาสตร์  3.45       165.0
# 3          64004  สมศักดิ์    22   ชาย     วิทยาศาสตร์   NaN       168.0
# 4          64005      สมใจ    19  หญิง  วิศวกรรมศาสตร์  3.89       160.0
# 6          64007     กิตติ    21  หญิง  วิศวกรรมศาสตร์   NaN       158.0
# 7          64008      จิรา    20  หญิง      ศิลปศาสตร์  2.98       180.0
# 8          64009    ชนาธิป    23   ชาย      ศิลปศาสตร์  3.34       163.0
# 9          64010      ดารา    21  หญิง      ศิลปศาสตร์  3.56       167.0
# 10         64011      ธีระ    20  หญิง     วิทยาศาสตร์  3.78         NaN
# 11         64012       นภา    22   ชาย     วิทยาศาสตร์   NaN       171.0
# 12         64013     บุญมี    20  หญิง  วิศวกรรมศาสตร์  3.23       169.0
# 13         64014     ปรีชา    21   ชาย      ศิลปศาสตร์  3.45       164.0
# ...

# %% [markdown]
# # **ใส่ค่าเฉลี่ยของGPA ในคอลัมน์ 'GPA' ที่เป็นค่า NaN**

# %%
mean_gpa = df['GPA'].mean()
df['GPA'].fillna(mean_gpa, inplace=True)
df['GPA'] = df['GPA'].round(2)

# %%
df
# Out:
#     รหัสนักศึกษา      ชื่อ  อายุ   เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0          64001     สมชาย    20   ชาย     วิทยาศาสตร์  3.21       170.0
# 1          64002    สมหญิง    21  หญิง     วิทยาศาสตร์  3.45       165.0
# 3          64004  สมศักดิ์    22   ชาย     วิทยาศาสตร์  3.44       168.0
# 4          64005      สมใจ    19  หญิง  วิศวกรรมศาสตร์  3.89       160.0
# 6          64007     กิตติ    21  หญิง  วิศวกรรมศาสตร์  3.44       158.0
# 7          64008      จิรา    20  หญิง      ศิลปศาสตร์  2.98       180.0
# 8          64009    ชนาธิป    23   ชาย      ศิลปศาสตร์  3.34       163.0
# 9          64010      ดารา    21  หญิง      ศิลปศาสตร์  3.56       167.0
# 10         64011      ธีระ    20  หญิง     วิทยาศาสตร์  3.78         NaN
# 11         64012       นภา    22   ชาย     วิทยาศาสตร์  3.44       171.0
# 12         64013     บุญมี    20  หญิง  วิศวกรรมศาสตร์  3.23       169.0
# 13         64014     ปรีชา    21   ชาย      ศิลปศาสตร์  3.45       164.0
# ...

# %% [markdown]
# # **ใส่ค่าเฉลี่ยของข้อมูล ในคอลัมน์ (ส่วนสูง_cm, น้ำหนัก_kg, ชั่วโมงเรียน_ต่อสัปดาห์) ที่มีค่าเป็น NaN**

# %%
mean_high = df['ส่วนสูง_cm'].mean()
df['ส่วนสูง_cm'].fillna(mean_high, inplace=True)
df['ส่วนสูง_cm'] = df['ส่วนสูง_cm'].round(2)


mean_weight = df['น้ำหนัก_kg'].mean()
df['น้ำหนัก_kg'].fillna(mean_weight, inplace=True)
df['น้ำหนัก_kg'] = df['น้ำหนัก_kg'].round(1)

mean_lern = df['ชั่วโมงเรียน_ต่อสัปดาห์'].mean()
df['ชั่วโมงเรียน_ต่อสัปดาห์'].fillna(mean_lern, inplace=True)
df['ชั่วโมงเรียน_ต่อสัปดาห์'] = df['ชั่วโมงเรียน_ต่อสัปดาห์'].astype(int)

# %%
df
# Out:
#     รหัสนักศึกษา      ชื่อ  อายุ   เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0          64001     สมชาย    20   ชาย     วิทยาศาสตร์  3.21       170.0
# 1          64002    สมหญิง    21  หญิง     วิทยาศาสตร์  3.45       165.0
# 3          64004  สมศักดิ์    22   ชาย     วิทยาศาสตร์  3.44       168.0
# 4          64005      สมใจ    19  หญิง  วิศวกรรมศาสตร์  3.89       160.0
# 6          64007     กิตติ    21  หญิง  วิศวกรรมศาสตร์  3.44       158.0
# 7          64008      จิรา    20  หญิง      ศิลปศาสตร์  2.98       180.0
# 8          64009    ชนาธิป    23   ชาย      ศิลปศาสตร์  3.34       163.0
# 9          64010      ดารา    21  หญิง      ศิลปศาสตร์  3.56       167.0
# 10         64011      ธีระ    20  หญิง     วิทยาศาสตร์  3.78       167.0
# 11         64012       นภา    22   ชาย     วิทยาศาสตร์  3.44       171.0
# 12         64013     บุญมี    20  หญิง  วิศวกรรมศาสตร์  3.23       169.0
# 13         64014     ปรีชา    21   ชาย      ศิลปศาสตร์  3.45       164.0
# ...

# %% [markdown]
# # Feature **Engineering**

# %%
data = df.copy()

# %%
data
# Out:
#     รหัสนักศึกษา      ชื่อ  อายุ   เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0          64001     สมชาย    20   ชาย     วิทยาศาสตร์  3.21       170.0
# 1          64002    สมหญิง    21  หญิง     วิทยาศาสตร์  3.45       165.0
# 3          64004  สมศักดิ์    22   ชาย     วิทยาศาสตร์  3.44       168.0
# 4          64005      สมใจ    19  หญิง  วิศวกรรมศาสตร์  3.89       160.0
# 6          64007     กิตติ    21  หญิง  วิศวกรรมศาสตร์  3.44       158.0
# 7          64008      จิรา    20  หญิง      ศิลปศาสตร์  2.98       180.0
# 8          64009    ชนาธิป    23   ชาย      ศิลปศาสตร์  3.34       163.0
# 9          64010      ดารา    21  หญิง      ศิลปศาสตร์  3.56       167.0
# 10         64011      ธีระ    20  หญิง     วิทยาศาสตร์  3.78       167.0
# 11         64012       นภา    22   ชาย     วิทยาศาสตร์  3.44       171.0
# 12         64013     บุญมี    20  หญิง  วิศวกรรมศาสตร์  3.23       169.0
# 13         64014     ปรีชา    21   ชาย      ศิลปศาสตร์  3.45       164.0
# ...

# %% [markdown]
# # **แปลงข้อมูลของคอลัมน์ 'คณะ' เป็นตัวเลข**

# %%
data_encoded = pd.get_dummies(data, columns=['คณะ']) * 1

# %%
data_encoded
# Out:
#     รหัสนักศึกษา      ชื่อ  อายุ   เพศ   GPA  ส่วนสูง_cm  น้ำหนัก_kg  \
# 0          64001     สมชาย    20   ชาย  3.21       170.0        65.0
# 1          64002    สมหญิง    21  หญิง  3.45       165.0        58.0
# 3          64004  สมศักดิ์    22   ชาย  3.44       168.0        70.0
# 4          64005      สมใจ    19  หญิง  3.89       160.0        52.0
# 6          64007     กิตติ    21  หญิง  3.44       158.0        48.0
# 7          64008      จิรา    20  หญิง  2.98       180.0        82.0
# 8          64009    ชนาธิป    23   ชาย  3.34       163.0        55.0
# 9          64010      ดารา    21  หญิง  3.56       167.0        60.0
# 10         64011      ธีระ    20  หญิง  3.78       167.0        68.0
# 11         64012       นภา    22   ชาย  3.44       171.0        62.9
# 12         64013     บุญมี    20  หญิง  3.23       169.0        72.0
# 13         64014     ปรีชา    21   ชาย  3.45       164.0        54.0
# 14         64015     พิมพ์    22  หญิง  3.67       162.0        56.0
# ...

# %% [markdown]
# # **การสร้าง Feature จากเกรด GPA**

# %%
g_data = data.copy()

g_data['ประเภทนักเรียน'] = pd.cut(g_data['GPA'],
                                  bins=[0, 3.25, 4.00],
                                  labels=['เรียนปกติ', 'เรียนเด่น'])

# %%
g_data
# Out:
#     รหัสนักศึกษา      ชื่อ  อายุ   เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0          64001     สมชาย    20   ชาย     วิทยาศาสตร์  3.21       170.0
# 1          64002    สมหญิง    21  หญิง     วิทยาศาสตร์  3.45       165.0
# 3          64004  สมศักดิ์    22   ชาย     วิทยาศาสตร์  3.44       168.0
# 4          64005      สมใจ    19  หญิง  วิศวกรรมศาสตร์  3.89       160.0
# 6          64007     กิตติ    21  หญิง  วิศวกรรมศาสตร์  3.44       158.0
# 7          64008      จิรา    20  หญิง      ศิลปศาสตร์  2.98       180.0
# 8          64009    ชนาธิป    23   ชาย      ศิลปศาสตร์  3.34       163.0
# 9          64010      ดารา    21  หญิง      ศิลปศาสตร์  3.56       167.0
# 10         64011      ธีระ    20  หญิง     วิทยาศาสตร์  3.78       167.0
# 11         64012       นภา    22   ชาย     วิทยาศาสตร์  3.44       171.0
# 12         64013     บุญมี    20  หญิง  วิศวกรรมศาสตร์  3.23       169.0
# 13         64014     ปรีชา    21   ชาย      ศิลปศาสตร์  3.45       164.0
# ...

# %% [markdown]
# # **การรวม Features สร้าง BMI จากส่วนสูงและน้ำหนัก และสร้าง สุขภาพ**

# %%
student_health = data.copy()


student_health['BMI'] = student_health['น้ำหนัก_kg'] / (student_health['ส่วนสูง_cm']/100)**2
student_health['สุขภาพ'] = pd.cut(student_health['BMI'],
                                   bins=[0, 18.5, 25, 30, 100],
                                   labels=['ผอม', 'ปกติ', 'อ้วน', 'อ้วนมาก'])

# %%
student_health
# Out:
#     รหัสนักศึกษา      ชื่อ  อายุ   เพศ             คณะ   GPA  ส่วนสูง_cm  \
# 0          64001     สมชาย    20   ชาย     วิทยาศาสตร์  3.21       170.0
# 1          64002    สมหญิง    21  หญิง     วิทยาศาสตร์  3.45       165.0
# 3          64004  สมศักดิ์    22   ชาย     วิทยาศาสตร์  3.44       168.0
# 4          64005      สมใจ    19  หญิง  วิศวกรรมศาสตร์  3.89       160.0
# 6          64007     กิตติ    21  หญิง  วิศวกรรมศาสตร์  3.44       158.0
# 7          64008      จิรา    20  หญิง      ศิลปศาสตร์  2.98       180.0
# 8          64009    ชนาธิป    23   ชาย      ศิลปศาสตร์  3.34       163.0
# 9          64010      ดารา    21  หญิง      ศิลปศาสตร์  3.56       167.0
# 10         64011      ธีระ    20  หญิง     วิทยาศาสตร์  3.78       167.0
# 11         64012       นภา    22   ชาย     วิทยาศาสตร์  3.44       171.0
# 12         64013     บุญมี    20  หญิง  วิศวกรรมศาสตร์  3.23       169.0
# 13         64014     ปรีชา    21   ชาย      ศิลปศาสตร์  3.45       164.0
# ...
